# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('salary_data_cleaned.csv')

# %%
df.head()
# Out:
#                                     Job Title             Salary Estimate  \
# 0                            Business Analyst  $51K-$97K (Glassdoor est.)
# 1  Sr. Business Analyst, Operations Analytics  $51K-$97K (Glassdoor est.)
# 2                             Support Analyst  $51K-$97K (Glassdoor est.)
# 3                     Senior Business Analyst  $51K-$97K (Glassdoor est.)
# 4          Business Intelligence (BI) Analyst  $51K-$97K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Intellinet is seeking a full time Business Ana...     4.5
# 1  Customer Experience Opportunity in Financial S...     3.4
# 2  Support Analyst\nBoston, MA\n\nWe will also co...     4.1
# 3  BASIC PURPOSE: Provides strategic consulting s...     3.8
# 4  MRI Software is seeking a Business Intelligenc...     3.4
#
#            Company Name     Location       Headquarters  \
# 0       Intellinet\n4.5  Atlanta, GA        Atlanta, GA
# 1    Advisor Group\n3.4  Atlanta, GA        Phoenix, AZ
# 2   FinancialForce\n4.1  Atlanta, GA  San Francisco, CA
# 3  FHLBank Atlanta\n3.8  Atlanta, GA        Atlanta, GA
# 4     MRI Software\n3.4  Atlanta, GA          Solon, OH
#
#                      Size  Founded  Type of ownership  ...        company_txt  \
# 0     51 to 200 employees     1993  Company - Private  ...       Intellinet\n
# 1  1001 to 5000 employees     2016  Company - Private  ...    Advisor Group\n
# 2   501 to 1000 employees     2009  Company - Private  ...   FinancialForce\n
# 3    201 to 500 employees     1932  Company - Private  ...  FHLBank Atlanta\n
# 4  1001 to 5000 employees     1971  Company - Private  ...     MRI Software\n
#
#   job_city job_state same_location  age_company  python_yn  R_yn tableau_yn  \
# 0  Atlanta        GA             1           27          0     1          0
# 1  Atlanta        GA             0            4          0     1          0
# 2  Atlanta        GA             0           11          0     1          0
# 3  Atlanta        GA             1           88          0     1          0
# 4  Atlanta        GA             0           49          0     1          0
#
#   excel_yn SAS_yn
# 0        1      0
# 1        1      0
# 2        1      0
# 3        1      0
# 4        0      0
#
# [5 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'min_salary', 'max_salary', 'avg_salary', 'company_txt', 'job_city',
#        'job_state', 'same_location', 'age_company', 'python_yn', 'R_yn',
#        'tableau_yn', 'excel_yn', 'SAS_yn'],
#       dtype='object')

# %%
# Create job title and seniority fields
# determine job description length
# competitor count
# remove extra characters off company name

# %%
df['Job Title'].unique()
# Out:
# array(['Business Analyst', 'Sr. Business Analyst, Operations Analytics',
#        'Support Analyst', 'Senior Business Analyst',
#        'Business Intelligence (BI) Analyst',
#        'FUTURE OPPORTUNITIES - Junior Analyst',
#        'Business Intelligence Manager', 'ERP Implementation Consultant',
#        'Analyst', 'Risk Analyst', 'Digital Banking Analyst',
#        'IT Business Analyst',
#        'EMR / HL7 Interface Implementation Analyst (Project Coordinator)',
#        'Business Analyst (IT)', 'Senior Analyst',
#        'Entry Level Business Analyst',
#        'Sales Operations & Strategy Analyst', 'CDC Program Analyst',
#        'IT Service Management Analyst I',
#        'Management Consulting - Future Opportunities',
#        'Business Systems Analyst', 'Associate Business Analyst',
#        'ADS SYSTEMS ANALYST SPECIALIST', 'Business Analyst Intern',
#        'eCommerce & Customer Efficiencies Analyst',
#        'Analyst (Platform Services)', 'Senior Business Systems Analyst',
#        'Business Analyst III', 'Systems Analyst- JDE World',
#        'CRM & Business Intelligence Analyst',
#        'Senior Consultant - DevOps - Nationwide Opportunities',
#        'Business Process Analyst', 'Online Business Analyst',
#        'Senior Consultant - Professional Services',
#        'Sr Business Systems Analyst',
#        'Business Analyst, Transportation Services',
#        'Technical Consultant', 'Lead Credit Analyst',
#        'Senior Business Intelligence Analyst',
#        'Business Insights Analyst', 'SR BUSINESS ANALYST',
#        'Sr. SaaS Business Analyst', 'Healthcare Business Analyst',
#        'Business Analyst (CRM)', 'Sr. Client Delivery Analyst',
#        'Compliance Analyst- Ad Review', 'Lead Business Analyst',
#        'Financial Application Analyst', 'Business Analyst/Tester',
#        'Business Analyst II', 'Salesforce Business Analyst',
#        'Technical Business Analyst', 'Business Process Analyst - Support',
#        'Business Analyst-Lenses', 'Data Analyst',
#        'Analyst (Success Services)', 'Implementation Consultant',
#        'SENIOR OPERATIONS BUSINESS ANALYST - HOME DEPOT DESIGN CENTER',
#        'Business Systems Analyst - HR Systems',
#        'Business Analyst/Project Manager',
#        'Business Analyst I and above (Implementations)',
#        'Quality Assurance Test Analyst',
#        'Business Analyst / Project Manager', 'Sr IT Business Analyst',
#        'Senior Systems Business Analyst',
#        'Salesforce Business Analyst/Administrator',
#        'Quality Assurance Analyst',
#        'QA Analyst - Quality Assurance / Test Analyst',
#        'Lead Business Analyst - Vendor Management', 'Credit Risk Analyst',
#        'GIS Business Analyst', 'Lead Implementation Consultant',
#        'Entry Level Accenture Infrastructure Advisory Analyst',
#        'Business Systems Analyst II', 'JPSC-7477 - Business Analyst',
#        'Analyst, Business Systems II', 'JPSC-7471 - Business analyst',
#        'SAP EWM Technical Business Analyst/Functional Configurator',
#        'Collection and Deduction Analyst', 'Sr Compliance Analyst',
#        'SENIOR BUSINESS INTELLIGENCE ANALYST', 'BI Business Analyst',
#        'Insy004 - Senior Business Systems Analyst',
#        'Business Process Analyst IV', 'IT Business Analyst III',
#        'Senior Financial Analyst', 'Business System Analyst',
#        'Costing Data Analyst', 'Business Intelligence Analyst (IT)',
#        'HR Business Analyst', 'Associate Financial Analyst',
#        'Sr. Financial Analyst - Sourcing and Procurement',
#        'Business Support Analyst 1', 'Financial Analyst',
#        'Workday Business Analyst',
#        'Business Support Analyst 3-WIC Deputy Director',
#        'Urgent - Business Analyst Trainee',
#        'Urgent - Business Analyst Level-1',
#        'GDOT- IT Ent Business Analyst 2', 'Sr. Business Analyst',
#        'Business Office Systems Analyst', 'Junior Business Analyst',
#        'Analyst, Investment Accounting',
#        'Urgent - Junior Level Business Analyst',
#        'Federal - Sr Business Analyst', 'Healthcare Reporting Analyst',
#        'Business Analyst-Atlanta, GA', 'Kronos Business Analyst',
#        'Business Analyst (QA)', 'Business Analyst (0-2 yrs)',
#        'IT Business Analyst - Business Analyst', 'Jr. Business Analyst',
#        'Senior Business Systems Analyst (PeopleSoft HCM)',
#        'ERP - Fixed Assets Functional Analyst',
#        'Lead Implementation Consultant, Encounter Management',
#        'Management Consultant', 'Sr. Business Analyst (PeopleSoft)',
#        'Business Systems Analyst (Financial domain)',
#        'Sr. Client Delivery Analyst - Federal',
#        'Data Analyst (Supply Chain) - May Reside Anywhere in the US - Up to 100% Travel',
#        'Business Analyst Level-1', 'Oracle EBS Business Systems Analyst',
#        'Business Analyst Trainee',
#        'Georgia Locals Only ::::::: Business Analyst Remote Atlanta, GA Maddy J',
#        'SENIOR ANALYST BUSINESS ANALYTICS MET',
#        'Entry level - Business Analyst',
#        'PeopleSoft Business Process Improvement Analyst', '#NAME?',
#        'Business Systems Analyst - IT Procurement',
#        'Supply Chain Analyst Intern', 'Business Analyst-Entry Level 1',
#        'WMS Business Systems Analyst', 'DHS-Business Analyst-Lenses',
#        'Business Analyst / Treasury',
#        'Analyst 3, Business Suppt & Analytics',
#        'Business Analyst / Loan Origination',
#        'ServiceNow Business Analyst', 'Analyst, Finance',
#        'Sr. Business Systems Analyst', 'Systems Analyst',
#        'Complnc Business Analyst Spv',
#        'Federal - Entry Level Functional Analyst - Supply Chain++',
#        'Business Analyst InternAtlanta',
#        'Quality Assurance Analyst, Senior',
#        'sap p2p business analyst with Ariba', 'Contract Analyst',
#        'Operations Analyst I',
#        'Senior Operations Business Analyst, Labor Engineering',
#        'Director - Customer Success Business Architect',
#        'Agile Business Analyst',
#        'Functional JD Edwards Business Analyst (JDE World)',
#        'SENIOR BUSINESS ANALYST', 'HDQC Business Analyst',
#        'Lead Business Analyst, Payments',
#        'Business Intelligence (BI) Analyst (Systems Analyst / Business Analyst)',
#        'BIO Business Solutions Analyst 5', 'Data Analyst 1',
#        'Business Analyst with US Payments', 'Brand Loyalty Analyst',
#        'Research Informatics & Business Analysis Manager',
#        'Senior Business Intelligence Engineer - Marketing & Analytics',
#        'Management And Program Analyst (staff Assistant)',
#        'Business Systems Analyst 5',
#        'Associate Sponsored Research Analyst',
#        'Microsoft Dynamics CRM Data Analyst',
#        'Pardot Business Analyst / Project Manager',
#        'Sr. Operations Business Analyst - Bilingual', 'Sr. Analyst',
#        'Digital Application Business Analyst, Cooper Lighting Solutions',
#        'Business Intelligence Analyst, Digital - AJC',
#        'Immigration Analyst (Assistant Paralegal)',
#        'Sales Business Analyst - Assessment Analyst - Modern Banking Platform',
#        'Advanced Business Intelligence Analyst', 'WSS Business Analyst',
#        'Application Analyst', 'Sfdc Business Analyst',
#        'BUSINESS SYSTEM ANALYST',
#        'E-Commerce Business Analyst / Project Manager',
#        'Sales Compensation Analyst',
#        'Staff Analyst, Service Partner Program', 'Sr Process Analyst',
#        'Business Analyst (Banking & Payment Domain Experience)',
#        'Senior Business Analyst - Accounting Systems',
#        'Business Analyst IBP', 'JPSC-7406 - Technical Business Analyst',
#        'PeopleSoft HCM Business/Data Analyst',
#        'Business Analyst - Atlanta', 'Database Analyst',
#        'Business Analyst (VBA & SQL)',
#        'Sr IT Business Analyst - Atlanta, GA', 'BUSINESS SYSTEMS ANALYST',
#        'Consultative Sales- Small Business Consulting',
#        'Business Analyst / Process Engineer',
#        'Software - Business Analyst',
#        'Analyst, Business Process Outsourcing',
#        'SR HR Services Business Analyst',
#        'Business Analyst-Trainee Level1', 'Junior Data Analyst',
#        'Business Incentives, Sr. Analyst',
#        'SENIOR BUSINESS ANALYST, MERCHANDISING OPERATIONS',
#        'Taleo Business Analyst',
#        'Senior Business Analyst (Workday/Deltek Contract Management)',
#        'Business Analyst-Entry level',
#        'Business Robotics Process Automation (RPA) Analyst or Consultant/Developer',
#        'RPA/Automation Business Analyst',
#        'Senior Business Analyst - Accounting Derivatives',
#        'Business Analyst III, Cybersecurity',
#        'Sr. Analyst, Data Services- Food Service and Distributor Data',
#        'Mainframe Sr.Systems Analyst',
#        'Business Analyst-Reconciliation Specialist',
#        'Enterprise PeopleSoft Analyst', 'Pardot Business Analyst',
#        'Business Analyst/Technical Analyst (ASAP)',
#        'Senior Business Analyst (WorkDay/DelTek/ERP)',
#        'Business Analyst Capital Markets exp only apply',
#        'Business Analyst-$TARS', 'GA TECH Senior Business Analyst',
#        'Business Analyst - Data Warehouse',
#        'Business Analyst with Telco and Video Experience',
#        'Senior Business Analyst - Accounting',
#        'SW Business Analyst / System Product Owner',
#        'DHS-IT Business Analyst-Lenses',
#        'Scientific Data Analyst with Security Clearance',
#        'Product Analysts (Systems/Business Analysis)',
#        'Urgent - Business Analyst (0-2 yrs Required)',
#        'Business Analyst / Product Owner (Payments Industry Experience)',
#        'HCM and Lawson S3 Business Analyst Consultant', 'Sales Analyst',
#        'Business Systems Programmer Analyst',
#        'Senior Data Analyst - Insider Risk',
#        'Sr. Global Business Process Analyst',
#        'GIS Business Analyst in Atlanta, Georgia',
#        'Process Reengineering & Business Analyst Lead',
#        'Senior Data Analyst',
#        'Enterprise Systems Senior Business Analyst – WMS',
#        'Business Data Analyst II', 'Deal Desk Analyst',
#        'Tableau Reporting Analyst', 'Senior Operations Business Analyst',
#        'Business Rules Engine Analyst', 'PDH Business Systems Analyst',
#        'CIS Cyber Threat Analyst II', 'Business Analyst 3',
#        'Supervisory Management Analyst', 'Cloud Infrastructure Analyst',
#        'Business Systems Analyst Senior - D1 Configuration Enablement',
#        'Applications Consultant 2 - Salesforce Business Analyst-Marketing Cloud',
#        'Urgent - Business Analyst',
#        'Enterprise Systems Senior Business Analyst – Manufacturing',
#        'Senior Business Analyst - Procurement Catalog',
#        'Business Analyst -Entry Level-Trainee 1',
#        'Pricing & Data Analyst',
#        'Management & Program Analyst (project Manager)',
#        'Business System Analyst ( Local only and Mortgage industry )',
#        'Business Analyst - Data Warehousing',
#        'Sponsored Research Financial Analyst',
#        'Operations Manager [Management Consultant-New York]',
#        'Urgent - Business Analyst (0 to 2 years)',
#        'ENTRY-LEVEL Business Analyst', 'Sr. Financial Analyst',
#        'Data Analyst III', 'System analyst', 'Senior Business Analysts',
#        'Senior Analyst, Category Experience - A/B Testing & Content',
#        'DCH - IT Business Analyst 4', 'Financial Management Analyst',
#        'Financial Analyst 2',
#        'Federal - Business Functional Consultant - Ft. Knox',
#        'Business Analyst-Fresher', 'Federal - SAP Business Analyst*',
#        'Exception Resolution Service Analyst', 'Business Analyst Fresher',
#        'IT Business Analyst / Project Manager - Environmental Software',
#        'Urgent - Business Analyst (Information Technology)',
#        'Business Analyst - Fresher',
#        'Business Intelligence Developer/Analyst',
#        'Sr. Business Systems Analyst - Supply Chain',
#        'Senior Business/Data Analyst', 'Senior Claims Data Analyst',
#        'IT Compliance Analyst I', 'DOL - IT Business Analyst 3',
#        'Business Analyst 2', 'Business Manager {Loans}'], dtype=object)

# %%
#Create function to simply diverse titles into few levels of interest
def title_simplifier(title):
    if 'it' in title.lower() or 'salesforce' in title.lower() or 'online' in title.lower() or 'saas' in title.lower() or 'software' in title.lower():
        return 'IT Analyst'
    elif 'supply' in title.lower():
        return 'Supply Chain Analyst'
    elif 'operations' in title.lower() or 'process' in title.lower():
        return 'Operations Analyst'
    elif 'manager' in title.lower():
        return 'Manager'
    elif 'director' in title.lower():
        return 'Director'
    elif 'data' in title.lower():
        return 'Data Analyst'
    elif 'consultant' in title.lower():
        return 'Consultant'
    elif 'business analyst' in title.lower():
        return 'Business Analyst'
    else:
        return 'Na'
    
#Create function to capture the seniority of job
def seniority(title):
    if 'jr' in title.lower() or 'junior' in title.lower() or 'entry' in title.lower() or 'trainee' in title.lower():
        return 'Junior'
    elif 'sr' in title.lower() or 'senior' in title.lower() or 'lead' in title.lower() or 'director' in title.lower() or 'manager' in title.lower():
        return 'Senior'
    elif 'intern' in title.lower() or 'internship' in title.lower():
        return 'Intern'
    else:
        return 'Na'

# %%
#create and check the count of simplified titles. titles of interest feature
df['job_simp'] = df['Job Title'].apply(title_simplifier)
df.job_simp.value_counts()
# Out:
# Business Analyst        235
# Na                      132
# IT Analyst               53
# Operations Analyst       23
# Data Analyst             23
# Manager                  12
# Consultant               11
# Supply Chain Analyst      6
# Director                  5
# Name: job_simp, dtype: int64

# %%
#create and check count of seniority feature
df['seniority'] = df['Job Title'].apply(seniority)
df.seniority.value_counts()
# Out:
# Na        337
# Senior    133
# Junior     26
# Intern      4
# Name: seniority, dtype: int64

# %%
#create a description length feature
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df.desc_len
# Out:
# 0      2351
# 1      8019
# 2      6045
# 3      4341
# 4      1946
#        ...
# 495    2994
# 496    6021
# 497    2797
# 498    2651
# 499    1730
# Name: desc_len, Length: 500, dtype: int64

# %%
#competitor count
df['num_comp']=df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)
df.num_comp.value_counts()
# Out:
# 0    394
# 3     62
# 2     37
# 1      7
# Name: num_comp, dtype: int64

# %%
#clean company name
df['Company Name'] = df['Company Name'].apply(lambda x: x.split('\n')[0])

# %%
df['Company Name'].value_counts()
# Out:
# Staffigo Technical Services, LLC    36
# Home Depot                          17
# Avacend, Inc.                       16
# Hunter Technical Resources           8
# HD Supply                            8
#                                     ..
# The AMES Companies, Inc.             1
# Anthem                               1
# TRC Professional Solutions           1
# P3S Corporation                      1
# Mitaja Corporation                   1
# Name: Company Name, Length: 291, dtype: int64

# %%
#see best number of bins for job description length
df['desc_len'].value_counts(bins=5)
# Out:
# (81.99199999999999, 3902.4]    335
# (3902.4, 7703.8]               158
# (7703.8, 11505.2]                6
# (15306.6, 19108.0]               1
# (11505.2, 15306.6]               0
# Name: desc_len, dtype: int64

# %%
#Beginning of Exploratory Analysis

# %%
df.describe()
# Out:
#            Rating      Founded  min_salary  max_salary  avg_salary  \
# count  500.000000   500.000000  500.000000  500.000000  500.000000
# mean     3.496600  1416.720000   50.276000   94.604000   72.440000
# std      1.453283   898.929308   10.399043   19.635026   14.835045
# min     -1.000000    -1.000000   32.000000   61.000000   46.500000
# 25%      3.300000    -1.000000   41.000000   76.000000   58.500000
# 50%      3.700000  1987.000000   51.000000   98.000000   74.000000
# 75%      4.300000  2005.000000   56.000000  103.000000   80.000000
# max      5.000000  2019.000000   69.000000  128.000000   98.500000
#
#        same_location  age_company  python_yn   R_yn  tableau_yn    excel_yn  \
# count     500.000000   500.000000  500.00000  500.0  500.000000  500.000000
# mean        0.304000    24.988000    0.04800    1.0    0.080000    0.616000
# std         0.460443    40.417062    0.21398    0.0    0.271565    0.486845
# min         0.000000    -1.000000    0.00000    1.0    0.000000    0.000000
# 25%         0.000000    -1.000000    0.00000    1.0    0.000000    0.000000
# 50%         0.000000    13.000000    0.00000    1.0    0.000000    1.000000
# 75%         1.000000    27.000000    0.00000    1.0    0.000000    1.000000
# max         1.000000   246.000000    1.00000    1.0    1.000000    1.000000
#
#            SAS_yn      desc_len    num_comp
# count  500.000000    500.000000  500.000000
# mean     0.068000   3298.034000    0.534000
# std      0.251998   1903.826818    1.069173
# min      0.000000    101.000000    0.000000
# 25%      0.000000   1955.500000    0.000000
# 50%      0.000000   3165.500000    0.000000
# 75%      0.000000   4412.250000    0.000000
# max      1.000000  19108.000000    3.000000

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'min_salary', 'max_salary', 'avg_salary', 'company_txt', 'job_city',
#        'job_state', 'same_location', 'age_company', 'python_yn', 'R_yn',
#        'tableau_yn', 'excel_yn', 'SAS_yn', 'job_simp', 'seniority', 'desc_len',
#        'num_comp'],
#       dtype='object')

# %%
#1st look at interesting continuous variables via Histograms
df.Rating.hist()
#Somewhat normal with low sd. Includes the nulls on left as -1

# %%
print(1.45/3.496)
print(14.8/72)
# Out:
# 0.41475972540045764
# 0.20555555555555557

# %%
df.avg_salary.hist()
# salary somewhat follows a normal distribution with high dispersion. Expected high standard deviation.

# %%
df.age_company.hist()
# age of company data appears to follow exponential distribution. Need to normalize for use  in regression

# %%
#2nd look at interesting continuous variables via Boxplots
df.boxplot(column = ['age_company','Rating','avg_salary'])

# %%
df.boxplot(column = 'Rating')

# %%
#3rd look at interesting continuous variables via Correlation Matrix
corr_select = df[['age_company','Rating','avg_salary','desc_len']].corr()
corr = df.corr()
print(corr) #see correlation between continuous variables
# Out:
#                  Rating   Founded  min_salary  max_salary  avg_salary  \
# Rating         1.000000  0.490372    0.047190    0.034140    0.039133
# Founded        0.490372  1.000000    0.045543    0.029725    0.035634
# min_salary     0.047190  0.045543    1.000000    0.946786    0.977052
# max_salary     0.034140  0.029725    0.946786    1.000000    0.993617
# avg_salary     0.039133  0.035634    0.977052    0.993617    1.000000
# same_location  0.036288  0.128366    0.045640    0.061000    0.056365
# age_company    0.111603  0.369515    0.119576    0.106675    0.112506
# python_yn     -0.050384  0.020042    0.005742    0.042691    0.030265
# R_yn                NaN       NaN         NaN         NaN         NaN
# tableau_yn    -0.046533  0.005280   -0.024865    0.007081   -0.004029
# excel_yn       0.012880 -0.006011    0.037997    0.022844    0.028435
# SAS_yn        -0.046974 -0.029384    0.027237    0.034209    0.032185
# desc_len      -0.072555  0.122054   -0.009124    0.008109    0.002168
# num_comp       0.093258  0.310823    0.096305    0.102212    0.101395
#
#                same_location  age_company  python_yn  R_yn  tableau_yn  \
# Rating              0.036288     0.111603  -0.050384   NaN   -0.046533
# Founded             0.128366     0.369515   0.020042   NaN    0.005280
# min_salary          0.045640     0.119576   0.005742   NaN   -0.024865
# max_salary          0.061000     0.106675   0.042691   NaN    0.007081
# avg_salary          0.056365     0.112506   0.030265   NaN   -0.004029
# same_location       1.000000     0.078376   0.075339   NaN    0.013463
# age_company         0.078376     1.000000  -0.040947   NaN    0.045003
# python_yn           0.075339    -0.040947   1.000000   NaN    0.520060
# R_yn                     NaN          NaN        NaN   NaN         NaN
# tableau_yn          0.013463     0.045003   0.520060   NaN    1.000000
# excel_yn            0.030110    -0.054111  -0.015082   NaN    0.050930
# SAS_yn              0.063282     0.145880   0.310993   NaN    0.154619
# desc_len            0.080237     0.234571   0.062180   NaN    0.100146
# num_comp            0.040024     0.247422   0.194320   NaN    0.128654
#
#                excel_yn    SAS_yn  desc_len  num_comp
# Rating         0.012880 -0.046974 -0.072555  0.093258
# Founded       -0.006011 -0.029384  0.122054  0.310823
# min_salary     0.037997  0.027237 -0.009124  0.096305
# max_salary     0.022844  0.034209  0.008109  0.102212
# avg_salary     0.028435  0.032185  0.002168  0.101395
# same_location  0.030110  0.063282  0.080237  0.040024
# age_company   -0.054111  0.145880  0.234571  0.247422
# python_yn     -0.015082  0.310993  0.062180  0.194320
# R_yn                NaN       NaN       NaN       NaN
# tableau_yn     0.050930  0.154619  0.100146  0.128654
# excel_yn       1.000000  0.017249  0.256220  0.009733
# SAS_yn         0.017249  1.000000  0.065463  0.073219
# desc_len       0.256220  0.065463  1.000000  0.122471
# num_comp       0.009733  0.073219  0.122471  1.000000

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df['Company Name'].value_counts()
# Out:
# Staffigo Technical Services, LLC    36
# Home Depot                          17
# Avacend, Inc.                       16
# Hunter Technical Resources           8
# HD Supply                            8
#                                     ..
# The AMES Companies, Inc.             1
# Anthem                               1
# TRC Professional Solutions           1
# P3S Corporation                      1
# Mitaja Corporation                   1
# Name: Company Name, Length: 291, dtype: int64

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'min_salary', 'max_salary', 'avg_salary', 'company_txt', 'job_city',
#        'job_state', 'same_location', 'age_company', 'python_yn', 'R_yn',
#        'tableau_yn', 'excel_yn', 'SAS_yn', 'job_simp', 'seniority', 'desc_len',
#        'num_comp'],
#       dtype='object')

# %%
#1st look at interesting categorical variables via Barplots

# %%
df_dim = df[['job_simp', 'Company Name', 'Location', 'Headquarters', 'Size', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 'job_city','same_location','python_yn','tableau_yn','excel_yn','SAS_yn', 'seniority']]

# %%
for i in df_dim.columns:
    dim_val = df[i].value_counts()
    print('Graph for %s: total = %d' % (i, len(dim_val)))
    plot = sns.barplot(x=dim_val.index, y=dim_val)
    plot.set_xticklabels(plot.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# Graph for job_simp: total = 9
# Graph for Company Name: total = 291
# Graph for Location: total = 19
# Graph for Headquarters: total = 144
# Graph for Size: total = 9
# Graph for Type of ownership: total = 11
# Graph for Industry: total = 49
# Graph for Sector: total = 24
# Graph for Revenue: total = 14
# Graph for job_city: total = 19
# Graph for same_location: total = 2
# Graph for python_yn: total = 2
# Graph for tableau_yn: total = 2
# Graph for excel_yn: total = 2
# Graph for SAS_yn: total = 2
# Graph for seniority: total = 4

# %%
for i in df_dim[['Location', 'Headquarters','Industry','Company Name']].columns:
    dim_val = df[i].value_counts()[:10]
    print('Graph for %s: total = %d' % (i, len(dim_val)))
    plot = sns.barplot(x=dim_val.index, y=dim_val)
    plot.set_xticklabels(plot.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# Graph for Location: total = 10
# Graph for Headquarters: total = 10
# Graph for Industry: total = 10
# Graph for Company Name: total = 10

# %%
#Look at how features relate to target variable via pivot tables

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'min_salary', 'max_salary', 'avg_salary', 'company_txt', 'job_city',
#        'job_state', 'same_location', 'age_company', 'python_yn', 'R_yn',
#        'tableau_yn', 'excel_yn', 'SAS_yn', 'job_simp', 'seniority', 'desc_len',
#        'num_comp'],
#       dtype='object')

# %%
#pivot average salary by job title and seniority
pd.pivot_table(df,index= ['job_simp','seniority'], values='avg_salary' )
# Out:
#                                 avg_salary
# job_simp             seniority
# Business Analyst     Intern      76.500000
#                      Junior      68.454545
#                      Na          73.050955
#                      Senior      72.027778
# Consultant           Na          73.857143
#                      Senior      83.375000
# Data Analyst         Junior      52.000000
#                      Na          68.941176
#                      Senior      65.300000
# Director             Senior      78.700000
# IT Analyst           Junior      74.000000
#                      Na          73.443182
#                      Senior      72.187500
# Manager              Senior      73.791667
# Na                   Junior      73.500000
#                      Na          73.372449
#                      Senior      72.954545
# Operations Analyst   Na          68.916667
#                      Senior      66.090909
# Supply Chain Analyst Intern      59.250000
#                      Junior      79.000000
#                      Na          82.500000
#                      Senior      51.500000

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %%
#pivot average salary by City location split job titles
pd.pivot_table(df,index= ['job_city','job_simp'], values='avg_salary', aggfunc='count').sort_values('job_city',ascending=True)
# Out:
#                                         avg_salary
# job_city          job_simp
# Alpharetta        Business Analyst              25
#                   Consultant                     1
#                   IT Analyst                     1
#                   Na                             7
#                   Operations Analyst             1
#                   Supply Chain Analyst           1
# Atlanta           Supply Chain Analyst           5
#                   Operations Analyst            22
#                   Na                           113
#                   Manager                       11
#                   Data Analyst                  19
#                   Director                       2
#                   Consultant                     9
#                   Business Analyst             192
#                   IT Analyst                    49
# Denver            Data Analyst                   1
# Duluth            Business Analyst               1
#                   Na                             2
# Dunwoody          Na                             2
#                   Business Analyst               2
# East Point        Business Analyst               1
# Ellenwood         Business Analyst               1
# Forest Park       Data Analyst                   1
# Johns Creek       Manager                        1
# Kennesaw          Consultant                     1
#                   IT Analyst                     2
#                   Na                             4
# Marietta          Director                       3
#                   Business Analyst               3
# Morrow            Na                             1
# Norcross          Business Analyst               1
#                   Data Analyst                   1
# Peachtree Corners Business Analyst               4
#                   Data Analyst                   1
#                   Na                             1
# Roswell           IT Analyst                     1
# Sandy Springs     Business Analyst               3
# Smyrna            Business Analyst               1
# Tucker            Na                             2
# Vinings           Business Analyst               1

# %%
#select features to loop pivot
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'min_salary', 'max_salary', 'avg_salary', 'company_txt', 'job_city',
#        'job_state', 'same_location', 'age_company', 'python_yn', 'R_yn',
#        'tableau_yn', 'excel_yn', 'SAS_yn', 'job_simp', 'seniority', 'desc_len',
#        'num_comp'],
#       dtype='object')

# %%
#chosen features to loop pivot: 'avg_salary','Rating', 'Company Name', 'Location', 'Size', 'Type of Ownership', 'Industry', 'Sector', 'num_comp', 'same_location', 'age_company', 'python_yn', 'R_yn', 'tableau_yn', 'excel_yn', 'SAS_yn', 'seniority', 'desc_len'

# %%
df_pivot = df[['Rating', 'Company Name', 'Location', 'Size', 'Type of ownership', 'Industry', 'Sector', 'num_comp', 'same_location', 'age_company', 'python_yn', 'R_yn', 'tableau_yn', 'excel_yn', 'SAS_yn', 'seniority', 'desc_len']]

# %%
for i in df_pivot.columns:
    print(i)
    print(pd.pivot_table(df,index= i, values='avg_salary').sort_values('avg_salary', ascending=False))
# Out:
# Rating
#         avg_salary
# Rating
#  2.6     86.250000
#  3.1     79.777778
#  2.7     79.450000
#  2.0     79.000000
#  4.5     78.566667
#  4.1     78.529412
#  4.4     77.750000
#  2.4     77.000000
#  3.8     75.833333
#  3.7     75.574074
#  3.5     75.048387
#  3.9     74.660714
#  4.0     73.750000
#  2.2     73.500000
#  3.2     73.416667
#  3.0     73.366667
#  4.9     72.850000
#  3.4     72.673913
#  3.6     70.944444
#  4.2     70.200000
#  4.3     69.950000
#  4.7     69.700000
#  3.3     68.840909
#  2.5     68.750000
#  5.0     68.468750
# -1.0     68.184211
#  2.8     68.000000
#  4.6     67.642857
#  4.8     67.125000
# Company Name
#                                                     avg_salary
# Company Name
# IBM                                                  98.500000
# Humana                                               98.500000
# ASAP                                                 98.500000
# Morehouse College                                    98.500000
# LanceSoft Inc                                        98.500000
# County Public Health                                 98.500000
# FOCUS Brands                                         98.500000
# Honeywell                                            95.000000
# Competent Systems, Inc                               95.000000
# Atlanta Hawks                                        95.000000
# Talend                                               95.000000
# Randstad US                                          95.000000
# TOTO USA                                             95.000000
# Colgate-Palmolive                                    95.000000
# North American Bancard LLC                           95.000000
# Cognizant Technology Solutions                       95.000000
# Synergy America, Inc                                 95.000000
# Symend                                               95.000000
# Red Clay Consulting                                  95.000000
# Ceramic Technics LTD                                 95.000000
# The Alexander Group (AZ)                             95.000000
# Deposco                                              95.000000
# Wolters Kluwer                                       95.000000
# TireHub                                              95.000000
# Morrison Group of Companies                          95.000000
# Metas Solutions                                      95.000000
# Amazon                                               95.000000
# Generis Tek Inc.                                     95.000000
# Central Business Solutions, Inc                      92.500000
# APN Software Services Inc.                           89.750000
# Signify                                              86.500000
# GreenSky                                             86.500000
# Scientific Games                                     86.500000
# Itamar Medical                                       86.500000
# Fragomen Worldwide                                   86.500000
# Genuine Parts Company                                86.500000
# ROI Healthcare Solutions                             86.500000
# Mailchimp                                            86.500000
# Expedite Technology                                  86.500000
# Randstad Technologies                                86.500000
# Career Guidant, Inc                                  86.500000
# JDC Group                                            86.500000
# Cox Media Group                                      86.500000
# eTeam Inc.                                           86.500000
# Telliant Systems                                     86.500000
# Allscripts                                           86.500000
# MRI Software                                         84.500000
# FHLBank Atlanta                                      84.500000
# Brightree                                            83.600000
# Emory University                                     83.300000
# Diverse Lynx                                         83.250000
# Paramount Software Solutions, Inc                    82.500000
# Pyramid                                              82.500000
# Maine Pointe                                         82.500000
# Aquesst                                              82.500000
# Advanced Technology Solutions, Inc                   82.500000
# Harness Solution                                     82.500000
# Symbioun Technologies                                81.000000
# Project Verte, Inc.                                  81.000000
# Voya Financial                                       80.833333
# AHEAD                                                80.000000
# HCL Technologies Ltd.                                80.000000
# Softpath System LLC                                  80.000000
# American Labz                                        80.000000
# International Market Centers                         80.000000
# Lincoln Financial                                    80.000000
# Maxonic, Inc.                                        80.000000
# LiveMindz                                            80.000000
# Amdocs, Inc.                                         80.000000
# Federal Home Loan                                    80.000000
# Global Payments                                      80.000000
# Levi, Ray & Shoup, Inc.                              80.000000
# Northside Hospital                                   80.000000
# Kaygen Inc.                                          80.000000
# Skiltrek                                             80.000000
# TRC Staffing Services                                80.000000
# Cetera Financial Group                               80.000000
# Talent Software Services                             80.000000
# Cooper Holdings, Inc.                                80.000000
# RSUI Group                                           80.000000
# The AMES Companies, Inc.                             80.000000
# Crescens Inc.                                        80.000000
# Artech LLC                                           80.000000
# CirrusLabs                                           80.000000
# Sharpedge Solutions Inc                              80.000000
# Safe-Guard Products International, LLC               80.000000
# Oglethorpe Power                                     80.000000
# Stellar Consulting Solutions                         80.000000
# Georgia State Government                             79.666667
# Edifecs                                              79.500000
# Collabera                                            79.500000
# Infor                                                79.000000
# Infinite Resource Solutions                          79.000000
# Comcast                                              79.000000
# Habitat for Humanity                                 79.000000
# Yoh - A Day & Zimmerman Company                      79.000000
# Icon Consultants                                     79.000000
# Leidos                                               79.000000
# Han IT Staffing                                      79.000000
# Republic National Distributing Company               79.000000
# ACI Worldwide                                        79.000000
# Bluesky Resource Solutions                           79.000000
# Delta Dental                                         79.000000
# UPS                                                  79.000000
# EVO Payments, Inc.                                   79.000000
# EshaIT                                               79.000000
# Meridian Bird Removal                                79.000000
# Networx Systems Inc.                                 79.000000
# McKesson                                             79.000000
# Executive Software Guild                             79.000000
# The Southern Company                                 79.000000
# Open Systems, Inc.                                   79.000000
# NASC GLOBAL                                          79.000000
# McKenney's Inc.                                      79.000000
# Mauser Packaging Solutions                           79.000000
# Masterapp Labs                                       79.000000
# MTech Systems USA                                    79.000000
# OnSolve                                              79.000000
# Hunter Gibbons - CHURN                               78.000000
# Trivest                                              78.000000
# TRC Professional Solutions                           78.000000
# Okaya Inc                                            78.000000
# VOYA                                                 78.000000
# Key Business Solutions, Inc.                         78.000000
# SOHO Square Solutions                                78.000000
# Wits Solutions                                       78.000000
# Stratfield Consulting                                78.000000
# nuVizz                                               78.000000
# Atlantic Capital Bancshares, Inc.                    78.000000
# Coca-Cola Business Services North America LLC        78.000000
# Dematic                                              78.000000
# Dell Technologies                                    78.000000
# Datum Software, Inc.                                 78.000000
# Avani Technology Solutions                           77.833333
# Urjanet                                              77.666667
# ExecuSource                                          77.666667
# HD Supply                                            77.312500
# AB2 Consulting Inc                                   77.166667
# Georgia Department of Labor                          77.000000
# RoofClaim, LLC                                       77.000000
# FIS                                                  76.750000
# CYNET SYSTEMS                                        76.750000
# Aptean                                               76.500000
# Agile                                                75.750000
# Hunter Technical Resources                           75.062500
# Thyssenkrupp                                         75.000000
# Compu-Vision Consulting Inc.                         74.250000
# TreeHouse Foods                                      74.000000
# National Software Management                         74.000000
# Federal Reserve Bank of Atlanta                      74.000000
# Mitaja Corporation                                   74.000000
# Mondo                                                74.000000
# LGE Community Credit Union                           74.000000
# Curant Health                                        74.000000
# Jabian Consulting                                    74.000000
# Globant                                              74.000000
# Kabbage                                              74.000000
# FinancialForce                                       74.000000
# Advisor Group                                        74.000000
# DRT Strategies, Inc.                                 74.000000
# Bennett Thrasher                                     74.000000
# Porter Novelli                                       74.000000
# Intellinet                                           74.000000
# Cloudreach                                           74.000000
# Ciber                                                74.000000
# Sharecare Inc.                                       74.000000
# Logos Infotech Inc                                   74.000000
# The Intersect Group                                  73.750000
# UST Global                                           73.750000
# BetterCloud                                          73.500000
# Vector Consulting, Inc                               73.500000
# Primerica, Inc.                                      73.500000
# P3S Corporation                                      73.500000
# Graphic Packaging International, Inc.                73.500000
# Cuboid IT Solutions                                  73.500000
# Vets First Choice                                    73.500000
# Conduent                                             73.500000
# Perficient                                           73.500000
# HRK Solutions                                        73.500000
# Aptuity Solutions, Inc                               73.500000
# COVETRUS INC                                         73.500000
# intellyk                                             73.500000
# nathan.k @cynetsystems.com                           73.500000
# Capgemini Government Solutions                       73.500000
# Kforce                                               73.250000
# Riskonnect                                           73.100000
# Department Of The Treasury                           72.500000
# VMware, Inc.                                         71.333333
# Truist                                               70.200000
# Orpine                                               69.250000
# RICEFW Technologies Inc                              69.200000
# Expert Technical Solutions                           69.000000
# Randstad                                             68.800000
# Home Depot                                           68.647059
# Oversight Systems                                    68.600000
# PSR Associates, Inc.                                 68.166667
# CNC Consulting                                       67.500000
# Crossroads Technologies                              67.500000
# Habitat for Humanity International (HFHI)            67.500000
# IDC Technologies                                     67.500000
# Capgemini                                            67.500000
# Saicon Consultants Inc                               67.500000
# Staff Financial Group                                67.500000
# Primerica                                            67.500000
# Steady                                               67.500000
# LexisNexis Risk Solutions                            67.500000
# Leidos Holdings Inc.                                 67.500000
# LG Hausys                                            67.500000
# Department Of Labor                                  67.500000
# Lorven Technologies Inc                              67.400000
# Avacend, Inc.                                        67.343750
# Trellis Rx                                           66.250000
# Georgia IT Inc.                                      66.250000
# GuidePoint Security                                  66.250000
# PROLIM Global Corporation                            66.250000
# MerchantE                                            66.250000
# Staffigo Technical Services, LLC                     66.041667
# Resource Logistics, Inc.                             66.000000
# Krystal                                              64.750000
# System Soft Technologies                             63.875000
# Action Technology, Inc.                              63.250000
# Chick-fil-A                                          63.200000
# Solekai Systems Corp                                 63.000000
# State of Georgia - State Properties Commission       62.750000
# Calsoft Labs                                         62.250000
# Yes-M Systems                                        61.500000
# PowerTeamServices                                    59.250000
# Gateway Recruiting, INC.                             59.250000
# Abacus Service Corporation                           59.250000
# Streamline Health Solutions                          59.000000
# Assurant                                             59.000000
# V.L.S. Systems                                       58.500000
# SunTechPros                                          58.500000
# Streamline Health                                    58.500000
# The Clorox Company                                   58.500000
# WestRock Company                                     58.500000
# Acumen Solutions                                     58.500000
# TSYS                                                 58.500000
# Turnberry Solutions                                  58.500000
# HonorVet Technologies                                58.500000
# Everest Technologies                                 58.500000
# New Relic                                            58.500000
# Southeastrans                                        58.500000
# IMC                                                  58.500000
# Intellitrans                                         58.500000
# Saicon Consultants                                   58.500000
# JAS USA                                              58.500000
# JAS Worldwide                                        58.500000
# Cogent IBS, Inc                                      58.500000
# GovStrive LLC                                        58.500000
# LeasePlan                                            58.500000
# Focused HR Solutions                                 58.500000
# NFI Industries                                       58.500000
# State of Georgia                                     57.000000
# Delta Information Systems, Inc.                      55.250000
# Ongig                                                52.000000
# Extremity Healthcare, Inc.                           52.000000
# JM Huber Corporation                                 52.000000
# Jnit Technologies                                    52.000000
# Insurance and Safety Fire Commissioner, Office ...   52.000000
# Global Resources                                     52.000000
# RELX Group                                           52.000000
# LeaseQuery                                           52.000000
# Anthem                                               52.000000
# GTS America                                          52.000000
# BrightLink                                           52.000000
# Apex Systems                                         52.000000
# Cushman & Wakefield                                  52.000000
# Argo Group US                                        52.000000
# Cambridge FX                                         51.500000
# Starr & Associates                                   51.500000
# Epiq eDiscovery Solutions, Inc.                      51.500000
# Enspire Partners, Inc.                               51.500000
# Infotech Sourcing                                    51.500000
# Lewis | James Professional                           51.500000
# The Judge Group                                      51.500000
# Duart Mull Capital Partners                          51.500000
# Americold Logistics                                  51.500000
# Healthgrades                                         51.500000
# New Signature                                        51.500000
# CTSR GROUP LLC                                       51.500000
# CharterUP                                            46.500000
# Zillion technologies Inc                             46.500000
# General Services Admin                               46.500000
# SIS software                                         46.500000
# Cox Communications                                   46.500000
# VAAS Professionals, LLC                              46.500000
# DeWolff Boberg & Associates                          46.500000
# First Advantage Corporation                          46.500000
# PEAK Technical Staffing USA                          46.500000
# AAA Global Technologies                              46.500000
# Location
#                            avg_salary
# Location
# Johns Creek, GA             98.500000
# East Point, GA              95.000000
# Morrow, GA                  95.000000
# Norcross, GA                89.750000
# Smyrna, GA                  86.500000
# Vinings, GA                 80.000000
# Ellenwood, GA               79.000000
# Peachtree Corners, GA       78.250000
# Tucker, GA                  77.000000
# Marietta, GA                76.166667
# Alpharetta, GA              75.236111
# Kennesaw, GA                74.214286
# Dunwoody, GA                73.625000
# Atlanta, GA                 71.939573
# Denver, CO                  67.500000
# Duluth, GA                  62.500000
# Sandy Springs, Fulton, GA   59.833333
# Forest Park, GA             58.500000
# Roswell, GA                 52.000000
# Size
#                          avg_salary
# Size
# Unknown                   79.900000
# 501 to 1000 employees     76.194444
# 1001 to 5000 employees    75.282609
# 10000+ employees          74.427083
# 5001 to 10000 employees   73.428571
# 51 to 200 employees       72.432432
# 201 to 500 employees      70.741667
# 1 to 50 employees         69.598485
# -1                        62.250000
# Type of ownership
#                                 avg_salary
# Type of ownership
# College / University             85.833333
# Unknown                          79.625000
# Nonprofit Organization           78.400000
# Other Organization               78.000000
# Company - Public                 75.306604
# Government                       72.766667
# Subsidiary or Business Segment   72.695652
# Company - Private                71.855556
# -1                               62.250000
# Contract                         60.000000
# Private Practice / Firm          46.500000
# Industry
#                                          avg_salary
# Industry
# Commercial Printing                       98.500000
# Sports & Recreation                       95.000000
# Energy                                    95.000000
# Metal & Mineral Manufacturing             95.000000
# Legal                                     86.500000
# News Outlet                               86.500000
# Automotive Parts & Accessories Stores     86.500000
# Colleges & Universities                   85.833333
# Wholesale                                 84.666667
# Advertising & Marketing                   82.000000
# Lending                                   80.250000
# Publishing                                80.000000
# Utilities                                 80.000000
# Consumer Products Manufacturing           79.800000
# Social Assistance                         79.000000
# Architectural & Engineering Services      79.000000
# Banks & Credit Unions                     78.200000
# Venture Capital & Private Equity          78.000000
# Construction                              77.250000
# Food & Beverage Manufacturing             76.000000
# Computer Hardware & Software              75.569767
# Aerospace & Defense                       75.166667
# Investment Banking & Asset Management     74.833333
# Consulting                                74.107143
# Brokerage Services                        74.000000
# Financial Transaction Processing          73.615385
# Biotech & Pharmaceuticals                 73.500000
# Federal Agencies                          73.000000
# Insurance Carriers                        72.821429
# Industrial Manufacturing                  72.750000
# State & Regional Agencies                 72.590909
# Enterprise Software & Network Solutions   72.437500
# Staffing & Outsourcing                    72.322581
# Internet                                  71.583333
# -1                                        70.965753
# IT Services                               70.486364
# Fast-Food & Quick-Service Restaurants     70.357143
# Health Care Services & Hospitals          69.500000
# Logistics & Supply Chain                  65.357143
# Accounting                                64.050000
# Home Centers & Hardware Stores            62.500000
# Health, Beauty, & Fitness                 59.500000
# Miscellaneous Manufacturing               58.500000
# Trucking                                  58.500000
# Car Rental                                58.500000
# Real Estate                               52.000000
# Chemical Manufacturing                    52.000000
# Telecommunications Services               52.000000
# Cable, Internet & Telephone Providers     46.500000
# Sector
#                                     avg_salary
# Sector
# Arts, Entertainment & Recreation     95.000000
# Oil, Gas, Energy & Utilities         87.500000
# Education                            85.833333
# Media                                83.250000
# Non-Profit                           79.000000
# Construction, Repair & Maintenance   77.250000
# Finance                              75.290323
# Aerospace & Defense                  75.166667
# Manufacturing                        74.821429
# Business Services                    73.924242
# Biotech & Pharmaceuticals            73.500000
# Insurance                            72.821429
# Government                           72.678571
# Information Technology               71.972678
# -1                                   70.965753
# Restaurants, Bars & Food Services    70.357143
# Health Care                          69.500000
# Retail                               67.300000
# Accounting & Legal                   66.090909
# Transportation & Logistics           64.500000
# Consumer Services                    59.500000
# Travel & Tourism                     58.500000
# Real Estate                          52.000000
# Telecommunications                   49.250000
# num_comp
#           avg_salary
# num_comp
# 3          77.129032
# 1          74.857143
# 0          71.769036
# 2          71.270270
# same_location
#                avg_salary
# same_location
# 1               73.703947
# 0               71.887931
# age_company
#              avg_salary
# age_company
#  59           98.500000
#  153          98.500000
#  109          98.500000
#  35           95.000000
#  32           95.000000
#  214          95.000000
#  184          95.000000
#  135          95.000000
#  34           86.500000
#  92           86.500000
#  129          86.500000
#  27           84.500000
#  49           84.500000
#  122          82.750000
#  36           82.250000
#  46           81.500000
#  69           80.250000
#  24           80.200000
#  41           80.000000
#  38           80.000000
#  246          80.000000
#  115          80.000000
#  29           79.666667
#  244          79.666667
#  7            79.100000
#  60           79.000000
#  80           79.000000
#  113          79.000000
#  45           79.000000
#  132          79.000000
#  187          79.000000
#  91           79.000000
#  44           79.000000
#  10           78.464286
#  19           78.375000
#  39           78.000000
#  201          78.000000
#  8            77.333333
#  40           77.000000
#  14           76.916667
#  26           76.750000
#  13           76.133333
#  4            76.100000
#  88           75.833333
#  53           75.833333
#  51           75.166667
#  209          75.000000
#  106          74.000000
#  48           74.000000
#  33           73.300000
#  54           73.250000
#  50           72.875000
#  25           72.625000
#  231          72.500000
#  21           72.227273
#  28           72.166667
#  20           72.142857
#  18           71.566667
# -1            71.503497
#  11           71.333333
#  22           70.764706
#  1            70.750000
#  52           70.700000
#  43           70.500000
#  16           70.437500
#  17           69.937500
#  3            69.500000
#  42           69.000000
#  31           68.750000
#  57           68.750000
#  15           67.916667
#  23           67.916667
#  12           66.737500
#  74           66.125000
#  9            64.750000
#  73           63.000000
#  6            58.500000
#  5            58.500000
#  107          58.500000
#  37           58.500000
#  140          52.000000
#  103          52.000000
#  72           52.000000
#  117          51.500000
#  58           46.500000
# python_yn
#            avg_salary
# python_yn
# 1           74.437500
# 0           72.339286
# R_yn
#       avg_salary
# R_yn
# 1          72.44
# tableau_yn
#             avg_salary
# tableau_yn
# 0            72.457609
# 1            72.237500
# excel_yn
#           avg_salary
# excel_yn
# 1          72.772727
# 0          71.906250
# SAS_yn
#         avg_salary
# SAS_yn
# 1        74.205882
# 0        72.311159
# seniority
#            avg_salary
# seniority
# Na          72.913947
# Senior      72.120301
# Junior      68.634615
# Intern      67.875000
# desc_len
#           avg_salary
# desc_len
# 3039       98.500000
# 6334       98.500000
# 4153       98.500000
# 1838       98.500000
# 817        98.500000
# 6456       98.500000
# 3911       98.500000
# 5104       98.500000
# 5502       98.500000
# 7631       98.500000
# 3361       98.500000
# 2051       98.500000
# 9212       98.500000
# 2868       98.500000
# 5872       95.000000
# 1398       95.000000
# 2854       95.000000
# 5606       95.000000
# 4827       95.000000
# 4843       95.000000
# 5078       95.000000
# 3014       95.000000
# 3167       95.000000
# 1863       95.000000
# 3429       95.000000
# 4403       95.000000
# 1772       95.000000
# 446        95.000000
# 1764       95.000000
# 6798       95.000000
# 3578       95.000000
# 4273       95.000000
# 4299       95.000000
# 4315       95.000000
# 6304       95.000000
# 2483       95.000000
# 4395       95.000000
# 3095       95.000000
# 4440       95.000000
# 2750       95.000000
# 5120       86.500000
# 5341       86.500000
# 2212       86.500000
# 3930       86.500000
# 1548       86.500000
# 4535       86.500000
# 4915       86.500000
# 1067       86.500000
# 1951       86.500000
# 933        86.500000
# 6166       86.500000
# 6099       86.500000
# 3473       86.500000
# 6391       86.500000
# 508        86.500000
# 2933       86.500000
# 459        86.500000
# 709        86.500000
# 952        86.500000
# 5505       86.500000
# 2983       86.500000
# 1044       86.500000
# 2346       86.500000
# 1822       86.500000
# 1946       84.500000
# 4341       83.000000
# 2801       82.750000
# 2707       82.500000
# 700        82.500000
# 4253       82.500000
# 3658       82.500000
# 2512       82.500000
# 696        82.500000
# 2217       82.500000
# 3712       82.500000
# 3284       82.500000
# 3242       82.500000
# 1358       82.500000
# 5039       82.500000
# 2071       82.000000
# 4689       81.500000
# 2446       81.250000
# 3357       81.000000
# 2482       81.000000
# 599        81.000000
# 1496       81.000000
# 2525       81.000000
# 2125       80.000000
# 2126       80.000000
# 101        80.000000
# 3391       80.000000
# 3371       80.000000
# 3336       80.000000
# 3199       80.000000
# 3131       80.000000
# 3025       80.000000
# 2823       80.000000
# 2515       80.000000
# 2518       80.000000
# 2604       80.000000
# 3164       80.000000
# 1632       80.000000
# 2576       80.000000
# 535        80.000000
# 929        80.000000
# 1017       80.000000
# 722        80.000000
# 1081       80.000000
# 721        80.000000
# 1204       80.000000
# 623        80.000000
# 1237       80.000000
# 550        80.000000
# 4616       80.000000
# 4555       80.000000
# 5746       80.000000
# 1445       80.000000
# 4445       80.000000
# 1580       80.000000
# 506        80.000000
# 7240       80.000000
# 3810       80.000000
# 3732       80.000000
# 3661       80.000000
# 153        80.000000
# 3934       79.500000
# 6654       79.000000
# 2772       79.000000
# 7675       79.000000
# 2773       79.000000
# 5880       79.000000
# 5817       79.000000
# 3644       79.000000
# 5638       79.000000
# 5504       79.000000
# 5475       79.000000
# 3656       79.000000
# 5353       79.000000
# 5322       79.000000
# 4720       79.000000
# 4509       79.000000
# 2602       79.000000
# 3845       79.000000
# 3393       79.000000
# 3421       79.000000
# 3813       79.000000
# 3534       79.000000
# 5474       79.000000
# 19108      79.000000
# 2555       79.000000
# 925        79.000000
# 2151       79.000000
# 2201       79.000000
# 1934       79.000000
# 1836       79.000000
# 1820       79.000000
# 1818       79.000000
# 1637       79.000000
# 1590       79.000000
# 2319       79.000000
# 1018       79.000000
# 999        79.000000
# 997        79.000000
# 1423       79.000000
# 804        79.000000
# 399        79.000000
# 1565       78.000000
# 2735       78.000000
# 4688       78.000000
# 3061       78.000000
# 3062       78.000000
# 4657       78.000000
# 4640       78.000000
# 3168       78.000000
# 694        78.000000
# 4731       78.000000
# 608        78.000000
# 3272       78.000000
# 3772       78.000000
# 3768       78.000000
# 3767       78.000000
# 143        78.000000
# 3399       78.000000
# 2131       78.000000
# 3457       78.000000
# 5222       78.000000
# 1360       78.000000
# 4837       78.000000
# 983        78.000000
# 5330       78.000000
# 2532       78.000000
# 7328       77.000000
# 3613       77.000000
# 4370       76.750000
# 2780       76.750000
# 5209       76.500000
# 3605       76.500000
# 2917       76.500000
# 2481       75.833333
# 3631       75.666667
# 1253       74.083333
# 6045       74.000000
# 4736       74.000000
# 5256       74.000000
# 3550       74.000000
# 3528       74.000000
# 8019       74.000000
# 3817       74.000000
# 3811       74.000000
# 4740       74.000000
# 3839       74.000000
# 3899       74.000000
# 1682       74.000000
# 1660       74.000000
# 5148       74.000000
# 1241       74.000000
# 6160       74.000000
# 4480       74.000000
# 1291       74.000000
# 4911       74.000000
# 5844       74.000000
# 4078       74.000000
# 2351       74.000000
# 3008       74.000000
# 3127       74.000000
# 2202       74.000000
# 3219       73.500000
# 2415       73.500000
# 1761       73.500000
# 1713       73.500000
# 3944       73.500000
# 4054       73.500000
# 4116       73.500000
# 3669       73.500000
# 1948       73.500000
# 5465       73.500000
# 1957       73.500000
# 6520       73.500000
# 6700       73.500000
# 2912       73.500000
# 2720       73.500000
# 2321       73.500000
# 2355       73.500000
# 5025       73.500000
# 4594       73.500000
# 2671       73.500000
# 3055       73.500000
# 3459       73.500000
# 9442       73.500000
# 2232       70.750000
# 4570       70.500000
# 2332       70.166667
# 1430       68.333333
# 3757       67.500000
# 5569       67.500000
# 228        67.500000
# 4654       67.500000
# 4874       67.500000
# 2170       67.500000
# 6973       67.500000
# 4545       67.500000
# 4527       67.500000
# 4353       67.500000
# 5245       67.500000
# 2535       67.500000
# 1157       67.500000
# 6437       67.500000
# 2633       67.500000
# 3341       67.500000
# 5768       67.500000
# 868        67.500000
# 3264       67.500000
# 2265       67.500000
# 3913       67.500000
# 3866       67.500000
# 841        67.500000
# 1064       66.666667
# 2811       66.250000
# 3547       66.250000
# 2969       66.250000
# 4193       66.250000
# 580        66.250000
# 5517       66.250000
# 5323       66.000000
# 1229       66.000000
# 2651       65.250000
# 2295       65.250000
# 1624       65.000000
# 4368       64.500000
# 2088       60.000000
# 4217       60.000000
# 2459       59.250000
# 3814       59.250000
# 3754       59.250000
# 1678       59.250000
# 4815       59.000000
# 2657       59.000000
# 2549       59.000000
# 5096       59.000000
# 6887       59.000000
# 2450       59.000000
# 6175       58.500000
# 503        58.500000
# 486        58.500000
# 2378       58.500000
# 893        58.500000
# 5944       58.500000
# 4812       58.500000
# 5955       58.500000
# 5293       58.500000
# 4836       58.500000
# 6212       58.500000
# 475        58.500000
# 1380       58.500000
# 2338       58.500000
# 4483       58.500000
# 3319       58.500000
# 3972       58.500000
# 3175       58.500000
# 4100       58.500000
# 3626       58.500000
# 2192       58.500000
# 1712       58.500000
# 3104       58.500000
# 3486       58.500000
# 2324       58.500000
# 4320       58.500000
# 4501       58.500000
# 2846       52.000000
# 4251       52.000000
# 3868       52.000000
# 3721       52.000000
# 3268       52.000000
# 140        52.000000
# 3715       52.000000
# 3687       52.000000
# 2029       52.000000
# 2697       52.000000
# 389        52.000000
# 3419       52.000000
# 5381       52.000000
# 5573       52.000000
# 3426       52.000000
# 2869       52.000000
# 1450       52.000000
# 5041       52.000000
# 1263       52.000000
# 3051       52.000000
# 1210       52.000000
# 3467       51.500000
# 9169       51.500000
# 2099       51.500000
# 7654       51.500000
# 3239       51.500000
# 2994       51.500000
# 6592       51.500000
# 1436       51.500000
# 514        51.500000
# 2230       51.500000
# 2134       51.500000
# 3446       51.500000
# 6021       51.500000
# 5984       51.500000
# 1684       51.500000
# 2797       51.500000
# 1091       51.500000
# 5530       51.500000
# 3040       51.500000
# 1730       51.500000
# 5712       51.500000
# 3214       51.500000
# 5308       51.500000
# 3236       51.500000
# 5390       51.500000
# 1705       51.500000
# 2761       49.250000
# 2441       46.500000
# 2077       46.500000
# 2293       46.500000
# 1305       46.500000
# 4884       46.500000
# 3531       46.500000
# 9543       46.500000
# 2937       46.500000
# 4976       46.500000
# 3362       46.500000
# 2988       46.500000
# 3241       46.500000
# 1950       46.500000
# 3964       46.500000
# 3939       46.500000
# 1890       46.500000
# 910        46.500000
# 3312       46.500000
# 1183       46.500000
# 5143       46.500000
# 1547       46.500000
# 3250       46.500000
# 2763       46.500000

# %%
#pivot average salary by revenue split by python
pd.pivot_table(df,index= 'Revenue',columns='python_yn', values='avg_salary', aggfunc='count')
# Out:
# python_yn                             0    1
# Revenue
# $1 to $2 billion (USD)             18.0  NaN
# $1 to $5 million (USD)             11.0  NaN
# $10 to $25 million (USD)           31.0  NaN
# $10+ billion (USD)                 35.0  7.0
# $100 to $500 million (USD)         54.0  3.0
# $2 to $5 billion (USD)             16.0  NaN
# $25 to $50 million (USD)           35.0  1.0
# $5 to $10 billion (USD)            27.0  NaN
# $5 to $10 million (USD)            21.0  1.0
# $50 to $100 million (USD)          52.0  2.0
# $500 million to $1 billion (USD)   12.0  1.0
# -1                                 21.0  1.0
# Less than $1 million (USD)         23.0  NaN
# Unknown / Non-Applicable          120.0  8.0

# %%
#import wordcloud and natural language tool kit modules
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
#generate wordcloud
word = "".join(df['Job Description'])

def punct_stop(text):
    """remove punctations and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for i in word_tokens:
        if i not in stop_words and i.isalpha():
            filtered.append(i.lower())
    return filtered

# %%
words_filtered = punct_stop(word)   

#text = "".join([i for i in words_filtered])
text = "".join(words_filtered)

wc = WordCloud(background_color='white', random_state=1, stopwords=STOPWORDS, max_words=10, width=800, height=1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation='bilinear')
plt.axis('off')
plt.show()
